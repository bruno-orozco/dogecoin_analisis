# %% [markdown]
# <a href="https://colab.research.google.com/github/bruno-orozco/dogecoin_analisis/blob/main/Dogecoin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Análisis del Dogecoin**
#
# ![efc333294e453832571903a38750cdea.jpg](data:image/jpeg;base64,...)

# %%
# Esta linea de código sirve para indicarle a Python que utilizaremos la libreía de Pandas

import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
#import plotly.graph_objects as go
import plotly.express as px

# %%
#Con esta linea de código permito a mi colab acceder a los archvios que se encuentran en mi Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Con esta línea de código redirecciono mi directorio a la ruta donde se encuentran los archivos que me interesan manipular

# %cd '/content/drive/My Drive/basededatos'
# !ls
# Out:
# /content/drive/My Drive/basededatos
# 'Análisis final Dogecoin.csv'	        Dogecoin.ipynb	 DOGE-USD.xlsx
# 'Análisis final Dogecoin seprado.csv'   DOGE-USD.csv

# %%
dogecoin = pd.read_csv('DOGE-USD.csv')
dogecoin
# Out:
#             Date      Open      High  ...     Close  Adj Close        Volume
# 0     2014-09-17  0.000293  0.000299  ...  0.000268   0.000268  1.463600e+06
# 1     2014-09-18  0.000268  0.000325  ...  0.000298   0.000298  2.215910e+06
# 2     2014-09-19  0.000298  0.000307  ...  0.000277   0.000277  8.835630e+05
# 3     2014-09-20  0.000276  0.000310  ...  0.000292   0.000292  9.930040e+05
# 4     2014-09-21  0.000293  0.000299  ...  0.000288   0.000288  5.391400e+05
# ...          ...       ...       ...  ...       ...        ...           ...
# 2479  2021-07-01  0.253828  0.260092  ...  0.244549   0.244549  2.463947e+09
# 2480  2021-07-02  0.243982  0.247997  ...  0.245264   0.245264  1.321471e+09
# 2481  2021-07-03  0.245106  0.250214  ...  0.246411   0.246411  9.170158e+08
# 2482  2021-07-04  0.246425  0.252567  ...  0.246483   0.246483  9.735115e+08
# 2483  2021-07-05  0.244649  0.245917  ...  0.241738   0.241738  1.067290e+09
#
# [2484 rows x 7 columns]

# %%
#Esta línea de código nos mostrará los primeros resultados de nuestro DataFram 
dogecoin.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2014-09-17  0.000293  0.000299  0.000260  0.000268   0.000268  1463600.0
# 1  2014-09-18  0.000268  0.000325  0.000267  0.000298   0.000298  2215910.0
# 2  2014-09-19  0.000298  0.000307  0.000275  0.000277   0.000277   883563.0
# 3  2014-09-20  0.000276  0.000310  0.000267  0.000292   0.000292   993004.0
# 4  2014-09-21  0.000293  0.000299  0.000284  0.000288   0.000288   539140.0
# 5  2014-09-22  0.000288  0.000301  0.000285  0.000298   0.000298   620222.0
# 6  2014-09-23  0.000298  0.000318  0.000295  0.000313   0.000313   739197.0
# 7  2014-09-24  0.000314  0.000353  0.000310  0.000348   0.000348  1277840.0
# 8  2014-09-25  0.000347  0.000383  0.000332  0.000375   0.000375  2393610.0
# 9  2014-09-26  0.000374  0.000467  0.000373  0.000451   0.000451  4722610.0

# %%
#La función tail (cola) nos mostrará los últimos registros
dogecoin.tail(3)
# Out:
#             Date      Open      High  ...     Close  Adj Close        Volume
# 2481  2021-07-03  0.245106  0.250214  ...  0.246411   0.246411  9.170158e+08
# 2482  2021-07-04  0.246425  0.252567  ...  0.246483   0.246483  9.735115e+08
# 2483  2021-07-05  0.244649  0.245917  ...  0.241738   0.241738  1.067290e+09
#
# [3 rows x 7 columns]

# %%
#La función sample nos muestra una serie de registros aleatorios
dogecoin.sample(3)
# Out:
#             Date      Open      High  ...     Close  Adj Close       Volume
# 1623  2019-02-26  0.002029  0.002050  ...  0.002023   0.002023   19292966.0
# 2324  2021-01-27  0.008255  0.008259  ...  0.007482   0.007482  204797186.0
# 627   2016-06-05  0.000237  0.000238  ...  0.000237   0.000237      67034.0
#
# [3 rows x 7 columns]

# %%
#Shape nos indicará el número de filas y columnas que componen nuestra base de datos
dogecoin.shape
# Out:
# (2484, 7)

# %%
#Size nos mostrará el producto de las filas x columnas
dogecoin.size
# Out:
# 17388

# %%
#Esta función nos indicará variables númericas de nuestra Base de Datos
dogecoin.describe()
# Out:
#               Open         High  ...    Adj Close        Volume
# count  2480.000000  2480.000000  ...  2480.000000  2.480000e+03
# mean      0.015054     0.016478  ...     0.015153  4.765325e+08
# std       0.065464     0.072582  ...     0.065697  2.950381e+09
# min       0.000087     0.000089  ...     0.000087  1.669500e+04
# 25%       0.000226     0.000230  ...     0.000226  2.402978e+05
# 50%       0.002089     0.002141  ...     0.002088  1.003520e+07
# 75%       0.003086     0.003186  ...     0.003087  5.886220e+07
# max       0.687801     0.737567  ...     0.684777  6.941068e+10
#
# [8 rows x 6 columns]

# %%
#Con esta función podemos ver el tipo de dato de nuestras vairables, y cuántas variables no nulas existen
dogecoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2484 non-null   object
#  1   Open       2480 non-null   float64
#  2   High       2480 non-null   float64
#  3   Low        2480 non-null   float64
#  4   Close      2480 non-null   float64
#  5   Adj Close  2480 non-null   float64
#  6   Volume     2480 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 136.0+ KB

# %%
#Esta línea de código nos ayudará a convertir el tipo de dato más adecuado para nuestras vairables
dogecoin.convert_dtypes().dtypes
# Out:
# Date          string
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         Int64
# dtype: object

# %%
#Esta función nos ayudará a identificar cuántos valores únicos tenemos en nuestro vector
dogecoin.nunique()
# Out:
# Date         2484
# Open         1516
# High         1524
# Low          1487
# Close        1510
# Adj Close    1510
# Volume       2480
# dtype: int64

# %%
#Esta función nos ayudará a transformar nuestro vector Date, a su correspondiente tipo de dato tiempo
# La documentación para explorar los tipo de formato para Python se encuentran en:
#https://docs.python.org/es/3/library/datetime.html
pd.to_datetime(dogecoin['Date'],
               errors="coerce",
               format="%Y-%m-%d")
# Out:
# 0      2014-09-17
# 1      2014-09-18
# 2      2014-09-19
# 3      2014-09-20
# 4      2014-09-21
#           ...
# 2479   2021-07-01
# 2480   2021-07-02
# 2481   2021-07-03
# 2482   2021-07-04
# 2483   2021-07-05
# Name: Date, Length: 2484, dtype: datetime64[ns]

# %%
# Para renombrar las etiquetas de nuestro DataFrame utilizamos la función rename
dogecoin.rename(columns={'Date': 'Fecha',
                         'Open': 'Precio de apertura',
                         'High': 'Precio más alto',
                         'Low': 'Precio más bajo',
                         'Close': 'Precio de cierre'}, inplace=True)

dogecoin
# Out:
#            Fecha  Precio de apertura  ...  Adj Close        Volume
# 0     2014-09-17            0.000293  ...   0.000268  1.463600e+06
# 1     2014-09-18            0.000268  ...   0.000298  2.215910e+06
# 2     2014-09-19            0.000298  ...   0.000277  8.835630e+05
# 3     2014-09-20            0.000276  ...   0.000292  9.930040e+05
# 4     2014-09-21            0.000293  ...   0.000288  5.391400e+05
# ...          ...                 ...  ...        ...           ...
# 2479  2021-07-01            0.253828  ...   0.244549  2.463947e+09
# 2480  2021-07-02            0.243982  ...   0.245264  1.321471e+09
# 2481  2021-07-03            0.245106  ...   0.246411  9.170158e+08
# 2482  2021-07-04            0.246425  ...   0.246483  9.735115e+08
# 2483  2021-07-05            0.244649  ...   0.241738  1.067290e+09
#
# [2484 rows x 7 columns]

# %%
dogecoin.columns
# Out:
# Index(['Fecha', 'Precio de apertura', 'Precio más alto', 'Precio más bajo',
#        'Precio de cierre', 'Adj Close', 'Volume'],
#       dtype='object')

# %%
#La función drop nos ayudará a eliminar elementos que deseemos en nuestro DataFrame
dogecoin.drop(['Adj Close'], axis=1, inplace=True)

dogecoin
# Out:
#            Fecha  Precio de apertura  ...  Precio de cierre        Volume
# 0     2014-09-17            0.000293  ...          0.000268  1.463600e+06
# 1     2014-09-18            0.000268  ...          0.000298  2.215910e+06
# 2     2014-09-19            0.000298  ...          0.000277  8.835630e+05
# 3     2014-09-20            0.000276  ...          0.000292  9.930040e+05
# 4     2014-09-21            0.000293  ...          0.000288  5.391400e+05
# ...          ...                 ...  ...               ...           ...
# 2479  2021-07-01            0.253828  ...          0.244549  2.463947e+09
# 2480  2021-07-02            0.243982  ...          0.245264  1.321471e+09
# 2481  2021-07-03            0.245106  ...          0.246411  9.170158e+08
# 2482  2021-07-04            0.246425  ...          0.246483  9.735115e+08
# 2483  2021-07-05            0.244649  ...          0.241738  1.067290e+09
#
# [2484 rows x 6 columns]

# %%
#Podemos agregar más columnas para nuestro análsis
dogecoin['Diferencia'] = dogecoin['Precio de cierre'] - dogecoin['Precio de apertura']
dogecoin['Rango'] = dogecoin['Precio más alto'] - dogecoin['Precio más bajo']
dogecoin['Promedio'] = ((dogecoin['Precio de cierre'] + dogecoin['Precio de apertura'] + dogecoin['Precio más alto'] + dogecoin['Precio más bajo']) / 4)
dogecoin
# Out:
#            Fecha  Precio de apertura  ...     Rango  Promedio
# 0     2014-09-17            0.000293  ...  0.000039  0.000280
# 1     2014-09-18            0.000268  ...  0.000058  0.000289
# 2     2014-09-19            0.000298  ...  0.000032  0.000289
# 3     2014-09-20            0.000276  ...  0.000043  0.000286
# 4     2014-09-21            0.000293  ...  0.000015  0.000291
# ...          ...                 ...  ...       ...       ...
# 2479  2021-07-01            0.253828  ...  0.021415  0.249286
# 2480  2021-07-02            0.243982  ...  0.009149  0.244023
# 2481  2021-07-03            0.245106  ...  0.007760  0.246046
# 2482  2021-07-04            0.246425  ...  0.009142  0.247225
# 2483  2021-07-05            0.244649  ...  0.005571  0.243163
#
# [2484 rows x 9 columns]

# %%
#Para agregar nuestra primera gráfica utilizamos Boxplot, para más detalles consultar en:
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.boxplot.html

distribucion = dogecoin[['Precio de apertura', 'Precio de cierre', 'Precio más alto', 'Precio más bajo', 'Diferencia', 'Rango', 'Promedio']]
grafica_distribucion = distribucion.boxplot(color = 'gray', figsize = [14, 6])
grafica_distribucion.set_title('Dogecoin datos históricos gráfica de disperción')
# Out:
# Text(0.5, 1.0, 'Dogecoin datos históricos gráfica de disperción')

# %%
#Mi análisis es este: ......
#Con la función plot, podemos agregar una gráfica lineal
#También con ella podremos agregar más graficos, para más información: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html
dogecoin = dogecoin.set_index(['Fecha'])
volatilidad = dogecoin[['Precio más alto', 'Precio más bajo']]
grafica_volatilidad = volatilidad.plot(kind = 'line', color = ('gold', 'black'), figsize = [14, 4], fontsize = 10)

# %%
dogecoin
# Out:
#             Precio de apertura  Precio más alto  ...     Rango  Promedio
# Fecha                                            ...
# 2014-09-17            0.000293         0.000299  ...  0.000039  0.000280
# 2014-09-18            0.000268         0.000325  ...  0.000058  0.000289
# 2014-09-19            0.000298         0.000307  ...  0.000032  0.000289
# 2014-09-20            0.000276         0.000310  ...  0.000043  0.000286
# 2014-09-21            0.000293         0.000299  ...  0.000015  0.000291
# ...                        ...              ...  ...       ...       ...
# 2021-07-01            0.253828         0.260092  ...  0.021415  0.249286
# 2021-07-02            0.243982         0.247997  ...  0.009149  0.244023
# 2021-07-03            0.245106         0.250214  ...  0.007760  0.246046
# 2021-07-04            0.246425         0.252567  ...  0.009142  0.247225
# 2021-07-05            0.244649         0.245917  ...  0.005571  0.243163
#
# [2484 rows x 8 columns]

# %%
#Con esta función quitaré el índice de fecha y lo regresaré a las col
dogecoin = dogecoin.reset_index('Fecha')
dogecoin
# Out:
#            Fecha  Precio de apertura  ...     Rango  Promedio
# 0     2014-09-17            0.000293  ...  0.000039  0.000280
# 1     2014-09-18            0.000268  ...  0.000058  0.000289
# 2     2014-09-19            0.000298  ...  0.000032  0.000289
# 3     2014-09-20            0.000276  ...  0.000043  0.000286
# 4     2014-09-21            0.000293  ...  0.000015  0.000291
# ...          ...                 ...  ...       ...       ...
# 2479  2021-07-01            0.253828  ...  0.021415  0.249286
# 2480  2021-07-02            0.243982  ...  0.009149  0.244023
# 2481  2021-07-03            0.245106  ...  0.007760  0.246046
# 2482  2021-07-04            0.246425  ...  0.009142  0.247225
# 2483  2021-07-05            0.244649  ...  0.005571  0.243163
#
# [2484 rows x 9 columns]

# %%
#Trnasformo la columna Fecha en tipo de dato datetime64

dogecoin['Fecha'] = pd.to_datetime(dogecoin['Fecha'])
dogecoin.dtypes
# Out:
# Fecha                 datetime64[ns]
# Precio de apertura           float64
# Precio más alto              float64
# Precio más bajo              float64
# Precio de cierre             float64
# Volume                       float64
# Diferencia                   float64
# Rango                        float64
# Promedio                     float64
# dtype: object

# %%
#Con esta función agruparé mis datos por semana, el argumento freq equivale en este caso a 1 week, es decir una semana
#https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases

doge2021 = dogecoin.copy(deep = True)
#doge2021 = doge2021.groupby(pd.Grouper(key = 'Fecha', freq = '1w')).sum()
doge2021 = doge2021[dogecoin['Fecha'].isin(pd.date_range('2021-01-01','2021-07-11'))]
doge2021 = doge2021.set_index(['Fecha'])
doge2021
# Out:
#             Precio de apertura  Precio más alto  ...     Rango  Promedio
# Fecha                                            ...
# 2021-01-01            0.004681         0.005685  ...  0.001070  0.005167
# 2021-01-02            0.005686         0.013698  ...  0.008114  0.008896
# 2021-01-03            0.010602         0.013867  ...  0.004458  0.010912
# 2021-01-04            0.009785         0.011421  ...  0.003543  0.009713
# 2021-01-05            0.009767         0.010219  ...  0.001247  0.009719
# ...                        ...              ...  ...       ...       ...
# 2021-07-01            0.253828         0.260092  ...  0.021415  0.249286
# 2021-07-02            0.243982         0.247997  ...  0.009149  0.244023
# 2021-07-03            0.245106         0.250214  ...  0.007760  0.246046
# 2021-07-04            0.246425         0.252567  ...  0.009142  0.247225
# 2021-07-05            0.244649         0.245917  ...  0.005571  0.243163
#
# [186 rows x 8 columns]

# %%
#Una vez que he agrupado mis datos por semana aplicaré una vez más mi código pero ahora absorverá el nuevo agrupamiento que he hecho por semanas
volatilidad = doge2021[['Precio más alto', 'Precio más bajo']]
grafica_volatilidad = volatilidad.plot(kind = 'line', color = ('gold', 'black'), figsize = [14, 4], fontsize = 10)
grafica_volatilidad.set_title('Volatilidad del Dogecoin en el 2021')
# Out:
# Text(0.5, 1.0, 'Volatilidad del Dogecoin en el 2021')

# %%
distribucion = doge2021[['Precio de apertura', 'Precio de cierre', 'Precio más alto', 'Precio más bajo', 'Diferencia', 'Rango', 'Promedio']]
grafica_distribucion = distribucion.boxplot(color = 'gray', figsize = [14, 6])
grafica_distribucion.set_title('Dogecoin 2021')
# Out:
# Text(0.5, 1.0, 'Dogecoin 2021')

# %%
#Agrego una función y creo un programa ramificado, si se cumple la primera condición
#el resultado en la nueva columna Análisis será El precio es bajo, sino se cumple, el 
#resultado será El precio es muy alto
def reglas(row):
  if row['Promedio'] < .005:
    return 'El precio es bajo'
  else:
    return 'El precio es muy alto'

dogecoin['Análisis'] = dogecoin.apply(reglas, axis=1)
dogecoin
# Out:
#           Fecha  Precio de apertura  ...  Promedio               Análisis
# 0    2014-09-17            0.000293  ...  0.000280      El precio es bajo
# 1    2014-09-18            0.000268  ...  0.000289      El precio es bajo
# 2    2014-09-19            0.000298  ...  0.000289      El precio es bajo
# 3    2014-09-20            0.000276  ...  0.000286      El precio es bajo
# 4    2014-09-21            0.000293  ...  0.000291      El precio es bajo
# ...         ...                 ...  ...       ...                    ...
# 2479 2021-07-01            0.253828  ...  0.249286  El precio es muy alto
# 2480 2021-07-02            0.243982  ...  0.244023  El precio es muy alto
# 2481 2021-07-03            0.245106  ...  0.246046  El precio es muy alto
# 2482 2021-07-04            0.246425  ...  0.247225  El precio es muy alto
# 2483 2021-07-05            0.244649  ...  0.243163  El precio es muy alto
#
# [2484 rows x 10 columns]

# %%
#https://plotly.com/python/linear-fits/
doge2021 = doge2021.reset_index(['Fecha'])
regresion_volume = px.scatter(doge2021, x='Fecha', y='Volume', trendline="ols")
regresion_volume.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bcc8e31f-59f8-47e1-aabf-819b4ab20970" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...

# %%
regresion_rango = px.scatter(doge2021, x='Fecha', y='Rango', trendline="ols")
regresion_rango.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="466067cd-1194-4149-a29f-b286e9a26786" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("466067cd-1194-4149-a29f-b286e9a26786")) {
#                     Plotly.newPlot(
#                         '466067cd-1194-4149-a29f-b286e9a26786',
# ...

# %%
dogecoin.to_csv('Análisis final Dogecoin.csv')
